# %% [markdown]
# <a href="https://colab.research.google.com/github/promila3/GoogleCodeJam/blob/master/LSTM_Implementation_for_Bitcoin_Price.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Credit - https://github.com/brynmwangy for code source

#install all the required dependancy libraries
# !pip install tensorflow #for prediction
# !pip install numpy  #for matrix multiplication
# !pip install pandas #define the data structures
# !pip install matplotlib #for visualization
# !pip install scikit-learn #for normalizing our data(scaling)

#importing the libraries
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import io
# %matplotlib inline

# %%
#loading the dataset
from google.colab import files
uploaded = files.upload()

# %%
#decoding the files as uploaded will be a dictionary of keys (the file names) and values (the encoded file objects)
btc = pd.read_csv(io.StringIO(uploaded['btc.csv'].decode('utf-8')))
btc.head()

# %%
#selecting only the column that we are going to use in the prediction process
data_to_use=btc['Close'].values
data_to_use
import matplotlib.pyplot as plt
plt.figure(figsize=(12,7), frameon=False, facecolor='brown', edgecolor='blue')
plt.title('Bitcoin prices from December 2014 to May 2018')
plt.xlabel('Days')
plt.ylabel('Price of Bitcoin')
plt.plot(data_to_use, label='Price')
plt.legend()
plt.show()

# %%
#data preprocessing(scaling)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data_to_use.reshape(-1, 1))
#plotting the data
import matplotlib.pyplot as plt
plt.figure(figsize=(12,7), frameon=False, facecolor='brown', edgecolor='blue')
plt.title('Bitcoin prices from December 2014 to May 2018')
plt.xlabel('Days')
plt.ylabel('Scaled price of Bitcoin')
plt.plot(scaled_data, label='Price')
plt.legend()
plt.show()

scaled_data
# Out:
# array([[ 1.32443891],
#        [ 1.30836052],
#        [ 1.34137813],
#        ...,
#        [-0.56145134],
#        [-0.56145134],
#        [-0.56356379]])

# %%
# This function is used to create Features and Labels datasets. By windowing the data.
#Input: data - dataset used in the project
#window_size - how many data points we are going to use to predict the next datapoint in the sequence 
#[Example: if window_size = 1 we are going to use only the previous day to predict todays stock prices]
#Outputs: X - features splitted into windows of datapoints (if window_size = 1, X = [len(data)-1, 1])
#y - 'labels', actually this is the next number in the sequence, this number we are trying to predict

def window_data(data, window_size):
    X = []
    y = []
    
    i = 0
    while (i + window_size) <= len(data) - 1:
        X.append(data[i:i+window_size])
        y.append(data[i+window_size])
        
        i += 1
    assert len(X) ==  len(y)
    return X, y
#windowing the data with window_data function
X, y = window_data(scaled_data, 7)


#we now split the data into training and test set
import numpy as np
X_train  = np.array(X[:1018])
y_train = np.array(y[:1018])

X_test = np.array(X[1018:])
y_test = np.array(y[1018:])

print("X_train size: {}".format(X_train.shape))
print("y_train size: {}".format(y_train.shape))
print("X_test size: {}".format(X_test.shape))
print("y_test size: {}".format(y_test.shape))

# %% [markdown]
# ![alt text](https://www.altumintelligence.com/altum-site/altum-intelligence/public/assets/time-series-prediction-using-lstm-deep-neural-networks/lstm_cell.png)

# %%
#we now define the network
#Hyperparameters used in the network
batch_size = 7 #how many windows of data we are passing at once
window_size = 7 #how big window_size is (Or How many days do we consider to predict next point in the sequence)
hidden_layer = 256 #How many units do we use in LSTM cell
clip_margin = 4 #To prevent exploding gradient, we use clipper to clip gradients below -margin or above this margin
learning_rate = 0.001 
epochs = 100

import tensorflow as tf
#we define the placeholders
inputs = tf.placeholder(tf.float32, [batch_size, window_size, 1])
targets = tf.placeholder(tf.float32, [batch_size, 1])



#weights and implementation of LSTM cell
# LSTM weights

#Weights for the input gate
weights_input_gate = tf.Variable(tf.truncated_normal([1, hidden_layer], stddev=0.05))
weights_input_hidden = tf.Variable(tf.truncated_normal([hidden_layer, hidden_layer], stddev=0.05))
bias_input = tf.Variable(tf.zeros([hidden_layer]))

#weights for the forget gate
weights_forget_gate = tf.Variable(tf.truncated_normal([1, hidden_layer], stddev=0.05))
weights_forget_hidden = tf.Variable(tf.truncated_normal([hidden_layer, hidden_layer], stddev=0.05))
bias_forget = tf.Variable(tf.zeros([hidden_layer]))

#weights for the output gate
weights_output_gate = tf.Variable(tf.truncated_normal([1, hidden_layer], stddev=0.05))
weights_output_hidden = tf.Variable(tf.truncated_normal([hidden_layer, hidden_layer], stddev=0.05))
bias_output = tf.Variable(tf.zeros([hidden_layer]))

#weights for the memory cell
weights_memory_cell = tf.Variable(tf.truncated_normal([1, hidden_layer], stddev=0.05))
weights_memory_cell_hidden = tf.Variable(tf.truncated_normal([hidden_layer, hidden_layer], stddev=0.05))
bias_memory_cell = tf.Variable(tf.zeros([hidden_layer]))

#Output layer weigts
weights_output = tf.Variable(tf.truncated_normal([hidden_layer, 1], stddev=0.05))
bias_output_layer = tf.Variable(tf.zeros([1]))


#function to compute the gate states
def LSTM_cell(input, output, state):
    
    input_gate = tf.sigmoid(tf.matmul(input, weights_input_gate) + tf.matmul(output, weights_input_hidden) + bias_input)
    
    forget_gate = tf.sigmoid(tf.matmul(input, weights_forget_gate) + tf.matmul(output, weights_forget_hidden) + bias_forget)
    
    output_gate = tf.sigmoid(tf.matmul(input, weights_output_gate) + tf.matmul(output, weights_output_hidden) + bias_output)
    
    memory_cell = tf.tanh(tf.matmul(input, weights_memory_cell) + tf.matmul(output, weights_memory_cell_hidden) + bias_memory_cell)
    
    state = state * forget_gate + input_gate * memory_cell
    
    output = output_gate * tf.tanh(state)
    return state, output
  
  
#we now define loop for the network
outputs = []
for i in range(batch_size): #Iterates through every window in the batch
  
    #for each batch I am creating batch_state as all zeros and output for that window which is all zeros at the beginning as well.
    batch_state = np.zeros([1, hidden_layer], dtype=np.float32) 
    batch_output = np.zeros([1, hidden_layer], dtype=np.float32)

    #for each point in the window we are feeding that into LSTM to get next output
    for ii in range(window_size):
        batch_state, batch_output = LSTM_cell(tf.reshape(inputs[i][ii], (-1, 1)), batch_state, batch_output)
                
    #last output is conisdered and used to get a prediction
    outputs.append(tf.matmul(batch_output, weights_output) + bias_output_layer)
outputs
# Out:
# [<tf.Tensor 'add_4543:0' shape=(1, 1) dtype=float32>,
#  <tf.Tensor 'add_4607:0' shape=(1, 1) dtype=float32>,
#  <tf.Tensor 'add_4671:0' shape=(1, 1) dtype=float32>,
#  <tf.Tensor 'add_4735:0' shape=(1, 1) dtype=float32>,
#  <tf.Tensor 'add_4799:0' shape=(1, 1) dtype=float32>,
#  <tf.Tensor 'add_4863:0' shape=(1, 1) dtype=float32>,
#  <tf.Tensor 'add_4927:0' shape=(1, 1) dtype=float32>]

# %%
#we define the loss
losses = []

for i in range(len(outputs)):
    losses.append(tf.losses.mean_squared_error(tf.reshape(targets[i], (-1, 1)), outputs[i]))
    
loss = tf.reduce_mean(losses)

#we define optimizer with gradient clipping
gradients = tf.gradients(loss, tf.trainable_variables())
clipped, _ = tf.clip_by_global_norm(gradients, clip_margin)
optimizer = tf.train.AdamOptimizer(learning_rate)
trained_optimizer = optimizer.apply_gradients(zip(gradients, tf.trainable_variables()))

#we now train the network
session = tf.Session()
session.run(tf.global_variables_initializer())
epochs = 30
for i in range(epochs):
    traind_scores = []
    ii = 0
    epoch_loss = []
    while(ii + batch_size) <= len(X_train):
        X_batch = X_train[ii:ii+batch_size]
        y_batch = y_train[ii:ii+batch_size]
        o, c, _ = session.run([outputs, loss, trained_optimizer], feed_dict={inputs:X_batch, targets:y_batch})
        
        epoch_loss.append(c)
        traind_scores.append(o)
        ii += batch_size
        print(traind_scores)
    if (i % 30) == 0:
        print('Epoch {}/{}'.format(i, epochs), ' Current loss: {}'.format(np.mean(epoch_loss)))

# %%
sup =[]
for i in range(len(traind_scores)):
    for j in range(len(traind_scores[i])):
        sup.append(traind_scores[i][j][0])

# %%
tests = []
i = 0
while i+batch_size <= len(X_test): 
  
    o = session.run([outputs],feed_dict={inputs:X_test[i:i+batch_size]})
    i += batch_size
    tests.append(o)
tests
# Out:
# [[[array([[-0.6251992]], dtype=float32),
#    array([[-0.6251655]], dtype=float32),
#    array([[-0.62529135]], dtype=float32),
#    array([[-0.6252497]], dtype=float32),
#    array([[-0.6254097]], dtype=float32),
#    array([[-0.62504286]], dtype=float32),
#    array([[-0.62504697]], dtype=float32)]],
#  [[array([[-0.6250054]], dtype=float32),
#    array([[-0.62494296]], dtype=float32),
#    array([[-0.62503266]], dtype=float32),
#    array([[-0.62501585]], dtype=float32),
#    array([[-0.6250325]], dtype=float32),
#    array([[-0.62497914]], dtype=float32),
#    array([[-0.6249165]], dtype=float32)]],
#  [[array([[-0.62486744]], dtype=float32),
#    array([[-0.624737]], dtype=float32),
#    array([[-0.6247549]], dtype=float32),
#    array([[-0.6247744]], dtype=float32),
#    array([[-0.62482256]], dtype=float32),
#    array([[-0.6248172]], dtype=float32),
#    array([[-0.6250782]], dtype=float32)]],
#  [[array([[-0.6250649]], dtype=float32),
#    array([[-0.6250841]], dtype=float32),
#    array([[-0.62505907]], dtype=float32),
#    array([[-0.6251368]], dtype=float32),
#    array([[-0.6251422]], dtype=float32),
#    array([[-0.6250667]], dtype=float32),
#    array([[-0.62508935]], dtype=float32)]],
#  [[array([[-0.62493616]], dtype=float32),
#    array([[-0.62490463]], dtype=float32),
#    array([[-0.6248034]], dtype=float32),
#    array([[-0.6243673]], dtype=float32),
#    array([[-0.6246914]], dtype=float32),
#    array([[-0.62481314]], dtype=float32),
#    array([[-0.6251368]], dtype=float32)]],
#  [[array([[-0.6251264]], dtype=float32),
#    array([[-0.62520224]], dtype=float32),
#    array([[-0.62513626]], dtype=float32),
#    array([[-0.6250874]], dtype=float32),
#    array([[-0.6252739]], dtype=float32),
#    array([[-0.62536913]], dtype=float32),
#    array([[-0.62538344]], dtype=float32)]],
#  [[array([[-0.6253213]], dtype=float32),
#    array([[-0.62516]], dtype=float32),
#    array([[-0.625305]], dtype=float32),
#    array([[-0.6254552]], dtype=float32),
#    array([[-0.6254003]], dtype=float32),
#    array([[-0.6255733]], dtype=float32),
#    array([[-0.625592]], dtype=float32)]],
#  [[array([[-0.6256318]], dtype=float32),
#    array([[-0.62556857]], dtype=float32),
#    array([[-0.6255037]], dtype=float32),
#    array([[-0.6255347]], dtype=float32),
#    array([[-0.6254906]], dtype=float32),
#    array([[-0.6255145]], dtype=float32),
#    array([[-0.62544197]], dtype=float32)]],
#  [[array([[-0.6254325]], dtype=float32),
#    array([[-0.62533814]], dtype=float32),
#    array([[-0.6256174]], dtype=float32),
#    array([[-0.6256857]], dtype=float32),
#    array([[-0.62567854]], dtype=float32),
#    array([[-0.62573516]], dtype=float32),
#    array([[-0.6257482]], dtype=float32)]],
#  [[array([[-0.62576294]], dtype=float32),
#    array([[-0.6257371]], dtype=float32),
#    array([[-0.6257461]], dtype=float32),
#    array([[-0.62584114]], dtype=float32),
#    array([[-0.62583387]], dtype=float32),
#    array([[-0.62583506]], dtype=float32),
#    array([[-0.6258641]], dtype=float32)]],
#  [[array([[-0.625839]], dtype=float32),
#    array([[-0.625856]], dtype=float32),
#    array([[-0.6259001]], dtype=float32),
#    array([[-0.6257886]], dtype=float32),
#    array([[-0.6257417]], dtype=float32),
#    array([[-0.6256613]], dtype=float32),
#    array([[-0.62566787]], dtype=float32)]],
#  [[array([[-0.6256401]], dtype=float32),
#    array([[-0.625644]], dtype=float32),
#    array([[-0.62564385]], dtype=float32),
#    array([[-0.62557715]], dtype=float32),
#    array([[-0.62561536]], dtype=float32),
#    array([[-0.6255818]], dtype=float32),
#    array([[-0.6256701]], dtype=float32)]],
#  [[array([[-0.6256976]], dtype=float32),
#    array([[-0.62574095]], dtype=float32),
#    array([[-0.6257394]], dtype=float32),
#    array([[-0.625664]], dtype=float32),
#    array([[-0.6256708]], dtype=float32),
#    array([[-0.6256536]], dtype=float32),
#    array([[-0.62567896]], dtype=float32)]],
#  [[array([[-0.62566257]], dtype=float32),
#    array([[-0.62554336]], dtype=float32),
#    array([[-0.6255552]], dtype=float32),
#    array([[-0.62559545]], dtype=float32),
#    array([[-0.62556183]], dtype=float32),
#    array([[-0.62549555]], dtype=float32),
#    array([[-0.6256235]], dtype=float32)]],
#  [[array([[-0.6257762]], dtype=float32),
#    array([[-0.6256543]], dtype=float32),
#    array([[-0.625577]], dtype=float32),
#    array([[-0.6255564]], dtype=float32),
#    array([[-0.6256247]], dtype=float32),
#    array([[-0.6256694]], dtype=float32),
#    array([[-0.6256185]], dtype=float32)]],
#  [[array([[-0.62583196]], dtype=float32),
#    array([[-0.6258313]], dtype=float32),
#    array([[-0.6258044]], dtype=float32),
#    array([[-0.62592727]], dtype=float32),
#    array([[-0.6258096]], dtype=float32),
#    array([[-0.6257078]], dtype=float32),
#    array([[-0.6256434]], dtype=float32)]],
#  [[array([[-0.6256703]], dtype=float32),
#    array([[-0.62562877]], dtype=float32),
#    array([[-0.6258106]], dtype=float32),
#    array([[-0.6258684]], dtype=float32),
#    array([[-0.6258755]], dtype=float32),
#    array([[-0.6258838]], dtype=float32),
#    array([[-0.6257662]], dtype=float32)]],
#  [[array([[-0.6259056]], dtype=float32),
#    array([[-0.62599546]], dtype=float32),
#    array([[-0.6256782]], dtype=float32),
#    array([[-0.62568164]], dtype=float32),
#    array([[-0.62569886]], dtype=float32),
#    array([[-0.6257447]], dtype=float32),
#    array([[-0.62561274]], dtype=float32)]],
#  [[array([[-0.62556493]], dtype=float32),
#    array([[-0.6253776]], dtype=float32),
#    array([[-0.6253302]], dtype=float32),
#    array([[-0.62525326]], dtype=float32),
#    array([[-0.62536967]], dtype=float32),
#    array([[-0.6253624]], dtype=float32),
#    array([[-0.6253654]], dtype=float32)]],
#  [[array([[-0.62551296]], dtype=float32),
#    array([[-0.625544]], dtype=float32),
#    array([[-0.62549055]], dtype=float32),
#    array([[-0.6256291]], dtype=float32),
#    array([[-0.6254405]], dtype=float32),
#    array([[-0.6255158]], dtype=float32),
#    array([[-0.6254957]], dtype=float32)]],
#  [[array([[-0.62558496]], dtype=float32),
#    array([[-0.6255619]], dtype=float32),
#    array([[-0.6252832]], dtype=float32),
#    array([[-0.62519974]], dtype=float32),
#    array([[-0.62535524]], dtype=float32),
#    array([[-0.62531286]], dtype=float32),
#    array([[-0.62536633]], dtype=float32)]],
#  [[array([[-0.6255183]], dtype=float32),
#    array([[-0.6249461]], dtype=float32),
#    array([[-0.62482363]], dtype=float32),
#    array([[-0.6249159]], dtype=float32),
#    array([[-0.6249643]], dtype=float32),
#    array([[-0.62492156]], dtype=float32),
#    array([[-0.6247218]], dtype=float32)]],
#  [[array([[-0.624705]], dtype=float32),
#    array([[-0.62475526]], dtype=float32),
#    array([[-0.62480706]], dtype=float32),
#    array([[-0.6251029]], dtype=float32),
#    array([[-0.6250394]], dtype=float32),
#    array([[-0.62508166]], dtype=float32),
#    array([[-0.62502384]], dtype=float32)]],
#  [[array([[-0.62504774]], dtype=float32),
#    array([[-0.6248375]], dtype=float32),
#    array([[-0.62496895]], dtype=float32),
#    array([[-0.6252821]], dtype=float32),
#    array([[-0.625313]], dtype=float32),
#    array([[-0.6253056]], dtype=float32),
#    array([[-0.625679]], dtype=float32)]],
#  [[array([[-0.62564623]], dtype=float32),
#    array([[-0.62559736]], dtype=float32),
#    array([[-0.62563366]], dtype=float32),
#    array([[-0.62568426]], dtype=float32),
#    array([[-0.62549335]], dtype=float32),
#    array([[-0.62553227]], dtype=float32),
#    array([[-0.62555724]], dtype=float32)]],
#  [[array([[-0.62565213]], dtype=float32),
#    array([[-0.6254831]], dtype=float32),
#    array([[-0.625649]], dtype=float32),
#    array([[-0.62569684]], dtype=float32),
#    array([[-0.62519604]], dtype=float32),
#    array([[-0.62559557]], dtype=float32),
#    array([[-0.6258554]], dtype=float32)]],
#  [[array([[-0.6258906]], dtype=float32),
#    array([[-0.62590337]], dtype=float32),
#    array([[-0.62588817]], dtype=float32),
#    array([[-0.6258661]], dtype=float32),
#    array([[-0.625742]], dtype=float32),
#    array([[-0.62584674]], dtype=float32),
#    array([[-0.6260228]], dtype=float32)]],
#  [[array([[-0.6258389]], dtype=float32),
#    array([[-0.62580055]], dtype=float32),
#    array([[-0.6256553]], dtype=float32),
#    array([[-0.625892]], dtype=float32),
#    array([[-0.626032]], dtype=float32),
#    array([[-0.6257536]], dtype=float32),
#    array([[-0.6257474]], dtype=float32)]],
#  [[array([[-0.62573165]], dtype=float32),
#    array([[-0.6251881]], dtype=float32),
#    array([[-0.62496287]], dtype=float32),
#    array([[-0.62528235]], dtype=float32),
#    array([[-0.6254568]], dtype=float32),
#    array([[-0.6255389]], dtype=float32),
#    array([[-0.62571514]], dtype=float32)]],
#  [[array([[-0.6257517]], dtype=float32),
#    array([[-0.6258419]], dtype=float32),
#    array([[-0.6257748]], dtype=float32),
#    array([[-0.62663907]], dtype=float32),
#    array([[-0.6266579]], dtype=float32),
#    array([[-0.62629324]], dtype=float32),
#    array([[-0.6261718]], dtype=float32)]],
#  [[array([[-0.6280304]], dtype=float32),
#    array([[-0.625582]], dtype=float32),
#    array([[-0.6249964]], dtype=float32),
#    array([[-0.6250003]], dtype=float32),
#    array([[-0.6250171]], dtype=float32),
#    array([[-0.6250958]], dtype=float32),
#    array([[-0.62515146]], dtype=float32)]],
#  [[array([[-0.6240802]], dtype=float32),
#    array([[-0.6240802]], dtype=float32),
#    array([[-0.6240802]], dtype=float32),
#    array([[-0.6240802]], dtype=float32),
#    array([[-0.6240802]], dtype=float32),
#    array([[-0.6240802]], dtype=float32),
#    array([[-0.6240802]], dtype=float32)]],
#  [[array([[-0.6240802]], dtype=float32),
#    array([[-0.6240802]], dtype=float32),
#    array([[-0.6240802]], dtype=float32),
#    array([[-0.6240802]], dtype=float32),
#    array([[-0.6240802]], dtype=float32),
#    array([[-0.6240802]], dtype=float32),
#    array([[-0.6240802]], dtype=float32)]],
#  [[array([[-0.6240802]], dtype=float32),
#    array([[-0.6241013]], dtype=float32),
#    array([[-0.62410134]], dtype=float32),
#    array([[-0.624102]], dtype=float32),
#    array([[-0.6241055]], dtype=float32),
#    array([[-0.62412137]], dtype=float32),
#    array([[-0.624132]], dtype=float32)]],
#  [[array([[-0.62393767]], dtype=float32),
#    array([[-0.6239376]], dtype=float32),
#    array([[-0.62396884]], dtype=float32),
#    array([[-0.6239726]], dtype=float32),
#    array([[-0.62399673]], dtype=float32),
#    array([[-0.62401295]], dtype=float32),
#    array([[-0.6238047]], dtype=float32)]]]

# %%
tests_new = []
for i in range(len(tests)):
  for j in range(len(tests[i][0])):
    tests_new.append(tests[i][0][j])
tests_new)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-e93c8d155606> in <module>()
#       3   for j in range(len(tests[i][0])):
#       4     tests_new.append(tests[i][0][j])
# ----> 5 tail(tests_new)
#
# NameError: name 'tail' is not defined

# %%
        

    
test_results = []
for i in range(1264):
      if i >= 1019:
        test_results.append(tests_new[i-1019])
      else:
        test_results.append(None)
test_results[1020]
# Out:
# array([[-0.6251655]], dtype=float32)

# %%
#we now plot predictions from the network
plt.figure(figsize=(16, 7))
plt.title('Bitcoin prices from December 2014 to May 2018')
plt.xlabel('Days')
plt.ylabel('Scaled Price of Bitcoin')
plt.plot(scaled_data, label='Original data')
plt.plot(sup, label='Training data')
plt.plot(test_results, label='Testing data')
plt.legend()
plt.show()
